# %%
### Test

# %%
$PSVersionTable
# Out:
# Name                           Value
# ----                           -----
# PSVersion                      5.1.18362.752
# PSEdition                      Desktop
# PSCompatibleVersions           {1.0, 2.0, 3.0, 4.0...}
# BuildVersion                   10.0.18362.752
# CLRVersion                     4.0.30319.42000
# WSManStackVersion              3.0
# PSRemotingProtocolVersion      2.3
# SerializationVersion           1.1.0.1

# %%
pwd
# Out:
# Path
# ----
# C:\Users\max_t\Documents

# %%
dir pwd -directory
# Out:
# dir : Cannot find path 'C:\Users\max_t\Documents\pwd' because it does not exist.
# At line:1 char:5
# + & { dir pwd -directory }
# +     ~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : ObjectNotFound: (C:\Users\max_t\Documents\pwd:String) [Get-ChildItem], ItemNotFoundExcep
#    tion
#     + FullyQualifiedErrorId : PathNotFound,Microsoft.PowerShell.Commands.GetChildItemCommand

# %%
dir $(pwd)
# Out:
#     Directory: C:\Users\max_t\Documents
#
#
# Mode                LastWriteTime         Length Name
# ----                -------------         ------ ----
# d-----        2/14/2020   1:17 PM                .ipynb_checkpoints
# d-----        7/15/2019  11:06 AM                Audacity
# d-----        1/14/2019  10:08 AM                Balabolka
# d-----        3/15/2020   2:41 PM                Camtasia Studio
# d-----        1/11/2019   8:11 PM                Custom Office Templates
# d-----         5/7/2019   3:46 PM                IISExpress
# d-----         2/7/2020   3:25 PM                Java_Programming_2020
# d-----        3/16/2020   1:38 PM                MVP_Summit_2020
# d-----         5/7/2019   3:46 PM                My Web Sites
# d-----         2/7/2020   3:38 PM                NetBeansProjects
# d-----         4/8/2019   9:46 PM                Orlando_IBJJF_04062019
# d-----        1/14/2019  10:10 AM                Panopreter 64-bit
# ...
